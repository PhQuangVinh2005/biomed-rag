# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

import sys, os
project_root = os.path.abspath(os.path.join(os.getcwd(), "../.."))
if project_root not in sys.path:
    sys.path.append(project_root)

from src.data_processing.bc5cdr import *

# %%
from data.external.ChemDisGene.pubtator import *

# %%
data_dir = os.path.join(project_root, 'data', 'external', 'ChemDisGene', 'data', 'ctd_derived')

abstract_path = os.path.join(data_dir, 'test_abstracts.txt')
relation_path = os.path.join(data_dir, 'test_relationships.tsv')

# %%
docs = parse_tsv_files_to_dict(abstracts_file=abstract_path, relations_file=relation_path, entities_file='')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 docs = parse_tsv_files_to_dict(abstracts_file=abstract_path, relations_file=relation_path, entities_file='')
#
# File d:\Study\Education\Projects\NLP\nlp-project\data\external\ChemDisGene\pubtator.py:435, in parse_tsv_files_to_dict(abstracts_file, entities_file, relations_file)
#     433 with open(abstracts_file) as f:
#     434     for line in f:
# --> 435         docid, title, abstract = line.strip().split("\t")
#     436         docs_dict[docid] = AnnotatedDocument(docid, title=title.strip(), abstract=abstract.strip())
#     437         n_docs += 1
#
# ValueError: not enough values to unpack (expected 3, got 1)
