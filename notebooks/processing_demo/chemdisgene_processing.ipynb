# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import ast

import sys, os
project_root = os.path.abspath(os.path.join(os.getcwd(), "../.."))
if project_root not in sys.path:
    sys.path.append(project_root)

from module.data_processing.ctd import *
from module.data_processing.bc5cdr import *

# %%
ctd = CTD()
bc5cdr = BC5CDR()

# %%
# df = ctd.process_ctd('train')

# df = pd.concat([df, ctd.process_ctd('dev'), ctd.process_ctd('test')], axis = 0).reset_index(drop = True)

# df
# Out:
# Reading from: d:\Study\Education\Projects\NLP\nlp-project\data\external\ChemDisGene\data\ctd_derived\train_abstracts.txt
# Reading from: d:\Study\Education\Projects\NLP\nlp-project\data\external\ChemDisGene\data\ctd_derived\train_relationships.tsv
# Reading from: d:\Study\Education\Projects\NLP\nlp-project\data\external\ChemDisGene\data\ctd_derived\dev_abstracts.txt
# Reading from: d:\Study\Education\Projects\NLP\nlp-project\data\external\ChemDisGene\data\ctd_derived\dev_relationships.tsv
# Reading from: d:\Study\Education\Projects\NLP\nlp-project\data\external\ChemDisGene\data\ctd_derived\test_abstracts.txt
# Reading from: d:\Study\Education\Projects\NLP\nlp-project\data\external\ChemDisGene\data\ctd_derived\test_relationships.tsv
#            pmid                                              title  \
# 0       1000984  The action of arterial hypertension on lipid a...
# 1       1001284                        Mephenytoin: a reappraisal.
# 2      10021906  [Immunoallergic reaction with hepatitis induce...
# 3      10022268  Role of inflammatory cytokines and nitric oxid...
# 4      10022522  Dual posttranscriptional targets of retinoic a...
# ...         ...                                                ...
# 80397  33146391  Early Gestational Exposure to Inhaled Ozone Im...
# 80398  33149750  Evaluation of Anti-Inflammatory Components of ...
# 80399  33259630  Gestational Cd Exposure in the CD-1 Mouse Indu...
# 80400  33328824  Soiled airway tracheal intubation and the effe...
# 80401  33405794  Antimicrobial Titanium Surface via Click-Immob...
#
#                                                 abstract  \
# 0      The purpose of the investigation was to study ...
# 1      Serum levels of mephenytoin (Mesantoin) and it...
# 2      We report the case of a 19-year old black West...
# 3      Exposure of humans and experimental animals to...
# 4      Retinoic acid-induced differentiation of the p...
# ...                                                  ...
# 80397  Exposure to air pollutants such as ozone (O3) ...
# 80398  Background: Guizhi Fuling capsule (GFC), a wel...
# 80399  There is compelling evidence that developmenta...
# 80400  Introduction: Vomiting and regurgitation are c...
# 80401  The use of antimicrobial peptides (AMPs)-funct...
#
#                                                 mentions  \
# 0      [{'text': 'hypertension', 'type': 'Disease', '...
# 1      [{'text': 'Mephenytoin', 'type': 'Chemical', '...
# 2      [{'text': 'hepatitis', 'type': 'Disease', 'id'...
# 3      [{'text': 'nitric oxide', 'type': 'Chemical', ...
# 4      [{'text': 'Retinoic acid', 'type': 'Chemical',...
# ...                                                  ...
# 80397  [{'text': 'Ozone', 'type': 'Chemical', 'id': '...
# 80398  [{'text': 'dysmenorrhea', 'type': 'Disease', '...
# 80399  [{'text': 'Cd', 'type': 'Chemical', 'id': 'D00...
# 80400  [{'text': 'Vomiting', 'type': 'Disease', 'id':...
# 80401  [{'text': 'peptides', 'type': 'Chemical', 'id'...
#
#                                            relationships
# 0      [{'type': 'chem_disease:therapeutic', 'subject...
# 1      [{'type': 'chem_disease:marker/mechanism', 'su...
# 2      [{'type': 'chem_disease:marker/mechanism', 'su...
# 3      [{'type': 'chem_gene:increases^expression', 's...
# 4      [{'type': 'chem_gene:decreases^expression', 's...
# ...                                                  ...
# 80397  [{'type': 'chem_gene:increases^transport', 'su...
# 80398  [{'type': 'chem_gene:increases^expression', 's...
# 80399  [{'type': 'chem_disease:marker/mechanism', 'su...
# 80400                                                 []
# 80401                                                 []
#
# [80402 rows x 5 columns]

# %%
# df['relationships'].iloc[0]
# Out:
# [{'type': 'chem_disease:therapeutic',
#   'subject_id': 'D000527',
#   'object_id': 'D006973',
#   'subject_type': 'Chemical',
#   'object_type': 'Disease'}]

# %%
# df['mentions'].iloc[0]
# Out:
# [{'text': 'hypertension',
#   'type': 'Disease',
#   'id': 'D006973',
#   'start': 23,
#   'end': 35},
#  {'text': 'lipid',
#   'type': 'Chemical',
#   'id': 'D008055',
#   'start': 39,
#   'end': 44},
#  {'text': 'Salt', 'type': 'Chemical', 'id': 'D012492', 'start': 76, 'end': 80},
#  {'text': 'hypertension',
#   'type': 'Disease',
#   'id': 'D006973',
#   'start': 125,
#   'end': 137},
#  {'text': 'lipid',
#   'type': 'Chemical',
#   'id': 'D008055',
#   'start': 208,
#   'end': 213},
#  {'text': 'salt',
#   'type': 'Chemical',
#   'id': 'D012492',
#   'start': 324,
#   'end': 328},
#  {'text': 'hypertension',
#   'type': 'Disease',
#   'id': 'D006973',
#   'start': 373,
#   'end': 385},
#  {'text': 'lipid',
#   'type': 'Chemical',
#   'id': 'D008055',
#   'start': 519,
#   'end': 524},
#  {'text': 'hypertension',
#   'type': 'Disease',
#   'id': 'D006973',
#   'start': 575,
#   'end': 587},
#  {'text': 'salt',
#   'type': 'Chemical',
#   'id': 'D012492',
#   'start': 604,
#   'end': 608},
#  {'text': 'hypertension',
#   'type': 'Disease',
#   'id': 'D006973',
#   'start': 617,
#   'end': 629},
#  {'text': 'hyperlipidaemia and hyperlipoproteinaemia',
#   'type': 'Disease',
#   'id': None,
#   'start': 633,
#   'end': 674},
#  {'text': 'renal hypertension',
#   'type': 'Disease',
#   'id': 'D006977',
#   'start': 696,
#   'end': 714},
#  {'text': 'lipid',
#   'type': 'Chemical',
#   'id': 'D008055',
#   'start': 725,
#   'end': 730},
#  {'text': 'cholesterol',
#   'type': 'Chemical',
#   'id': 'D002784',
#   'start': 818,
#   'end': 829},
#  {'text': 'hypertension',
#   'type': 'Disease',
#   'id': 'D006973',
#   'start': 892,
#   'end': 904},
#  {'text': 'lipid',
#   'type': 'Chemical',
#   'id': 'D008055',
#   'start': 920,
#   'end': 925},
#  {'text': 'salt',
#   'type': 'Chemical',
#   'id': 'D012492',
#   'start': 987,
#   'end': 991},
#  {'text': 'hypertension',
#   'type': 'Disease',
#   'id': 'D006973',
#   'start': 1000,
#   'end': 1012},
#  {'text': 'hypertension',
#   'type': 'Disease',
#   'id': 'D006973',
#   'start': 1054,
#   'end': 1066},
#  {'text': 'hypotensive',
#   'type': 'Disease',
#   'id': 'D007022',
#   'start': 1139,
#   'end': 1150},
#  {'text': 'prostaglandin E1',
#   'type': 'Chemical',
#   'id': 'D000527',
#   'start': 1151,
#   'end': 1167},
#  {'text': 'lipid',
#   'type': 'Chemical',
#   'id': 'D008055',
#   'start': 1183,
#   'end': 1188},
#  {'text': 'hypertension',
#   'type': 'Disease',
#   'id': 'D006973',
#   'start': 1261,
#   'end': 1273},
#  {'text': 'cholesterol',
#   'type': 'Chemical',
#   'id': 'D002784',
#   'start': 1280,
#   'end': 1291},
#  {'text': 'free fatty acids',
#   'type': 'Chemical',
#   'id': 'D005230',
#   'start': 1338,
#   'end': 1354},
#  {'text': 'hypertension',
#   'type': 'Disease',
#   'id': 'D006973',
#   'start': 1405,
#   'end': 1417},
#  {'text': 'cholesterol',
#   'type': 'Chemical',
#   'id': 'D002784',
#   'start': 1430,
#   'end': 1441},
#  {'text': 'lipid',
#   'type': 'Chemical',
#   'id': 'D008055',
#   'start': 1508,
#   'end': 1513},
#  {'text': 'hypertensive',
#   'type': 'Disease',
#   'id': 'D006973',
#   'start': 1600,
#   'end': 1612},
#  {'text': 'atherosclerosis',
#   'type': 'Disease',
#   'id': 'D050197',
#   'start': 1681,
#   'end': 1696}]

# %%
# lookup_table = ctd.create_lookup_table(df)

# lookup_table
# Out:
#                                           text      type       id
# 0                                 Hypertension   Disease  D006973
# 1                                        Lipid  Chemical  D008055
# 2                                         Salt  Chemical  D012492
# 3                           Renal hypertension   Disease  D006977
# 4                                  Cholesterol  Chemical  D002784
# ...                                        ...       ...      ...
# 115274                                   Scfas  Chemical  D005232
# 115275                                   G6pdx      Gene    14381
# 115276              Fms-like tyrosine kinase-1      Gene     2321
# 115277                     Benzoylpaeoniflorin  Chemical  C047591
# 115278  Impaired offspring glucose homeostasis   Disease  D018149
#
# [115279 rows x 3 columns]
