# %%
import pandas as pd
import os
import faiss
import numpy as np

# %%
NOTEBOOK_DIR= os.getcwd()
BASE_DIR= os.path.join(NOTEBOOK_DIR, "..", "..")
JSON_FILE= os.path.join(NOTEBOOK_DIR, "data", "processed","bioasq","bioasq.json")
INDEX_DIR = os.path.join(BASE_DIR, "data","vectorstore")
INDEX_FILE = os.path.join(INDEX_DIR, "index.bin")
EMBED_FILE= os.path.join(INDEX_DIR, "embeddings.npy")

# %%
index= faiss.read_index(INDEX_FILE)
embeddings= np.load(EMBED_FILE)
